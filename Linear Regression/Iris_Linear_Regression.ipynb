# %% [markdown]
# <a href="https://colab.research.google.com/github/BrightToughson/forex-signal-assistant/blob/main/Iris_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

from sklearn import linear_model

# %% [markdown]
# Getting libaries

# %%
df = pd.read_csv('/content/drive/MyDrive/dummy_height_weight_age.csv')

# %% [markdown]
# declaring a variable (df = dataframe)
# using pandas to read an excel file with the path

# %%
df
# Out:
#     ID  Height (cm)  Weight (kg)  Age (years)
# 0    1          160           55           22
# 1    2          172           68           28
# 2    3          181           75           35
# 3    4          154           49           19
# 4    5          167           62           25
# 5    6          176           70           31
# 6    7          162           58           24
# 7    8          169           64           27
# 8    9          158           52           20
# 9   10          185           80           33
# 10  11          178           73           29
# 11  12          165           60           23
# 12  13          182           78           36
# 13  14          161           56           21
# 14  15          170           66           26
# 15  16          175           72           30
# 16  17          159           53           19
# 17  18          180           76           34
# 18  19          163           57           22
# ...

# %%
df.head()
# Out:
#    ID  Height (cm)  Weight (kg)  Age (years)
# 0   1          160           55           22
# 1   2          172           68           28
# 2   3          181           75           35
# 3   4          154           49           19
# 4   5          167           62           25

# %% [markdown]
# Displaying the dataframe the beginning 5 sets

# %%
df.tail()
# Out:
#     ID  Height (cm)  Weight (kg)  Age (years)
# 15  16          175           72           30
# 16  17          159           53           19
# 17  18          180           76           34
# 18  19          163           57           22
# 19  20          177           71           32

# %% [markdown]
# Displaying the dataframe the ending 5 sets

# %%
df.isna()
# Out:
#        ID  Height (cm)  Weight (kg)  Age (years)
# 0   False        False        False        False
# 1   False        False        False        False
# 2   False        False        False        False
# 3   False        False        False        False
# 4   False        False        False        False
# 5   False        False        False        False
# 6   False        False        False        False
# 7   False        False        False        False
# 8   False        False        False        False
# 9   False        False        False        False
# 10  False        False        False        False
# 11  False        False        False        False
# 12  False        False        False        False
# 13  False        False        False        False
# 14  False        False        False        False
# 15  False        False        False        False
# 16  False        False        False        False
# 17  False        False        False        False
# ...

# %% [markdown]
# Checking for missing values

# %%
df.isnull()
# Out:
#        ID  Height (cm)  Weight (kg)  Age (years)
# 0   False        False        False        False
# 1   False        False        False        False
# 2   False        False        False        False
# 3   False        False        False        False
# 4   False        False        False        False
# 5   False        False        False        False
# 6   False        False        False        False
# 7   False        False        False        False
# 8   False        False        False        False
# 9   False        False        False        False
# 10  False        False        False        False
# 11  False        False        False        False
# 12  False        False        False        False
# 13  False        False        False        False
# 14  False        False        False        False
# 15  False        False        False        False
# 16  False        False        False        False
# 17  False        False        False        False
# ...

# %% [markdown]
# Checking for null values

# %%
# %matplotlib inline
plt.scatter(df['Height (cm)'],df['Weight (kg)'])

# %% [markdown]
# Displaying the values in scatterplot

# %%
from sklearn.datasets import load_iris
iris = load_iris()
x = iris.data
y = iris.target

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error: {rmse}")
print(f"R-squared: {r2}")
# Out:
# Root Mean Squared Error: 0.24194317973455248
# R-squared: 0.9060911729089851

# %%
np.random.seed(42)

height = np.random.randint(150, 200, 100)
age = np.random.randint(18, 65, 100)

weight = height * 0.7 + age * 0.2 + np.random.normal(0, 10, 100)



df = pd.DataFrame({'Height (cm)': height, 'Weight (kg)': weight, 'Age': age})
print("Preview of dataset:")
print(df.head())

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("\nMobel Evaluation")
print(f"Mean Squared Error: {mse:2f}")
print(f"Root Mean Squared Error: {rmse:2f}")
print(f"R-squared: {r2:2f}")

results = pd.DataFrame({'Actual Weight': y_test, 'Predicted Weight': y_pred})
print("\nActual vs. Predicted Weights:\n")
print(results.head())

plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color='red', alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='blue', linewidth=2)
plt.xlabel('Actual Weight')
plt.ylabel('Predicted Weight')
plt.title('Actual vs. Predicted Weights')
plt.show()

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['Height (cm)'], df['Weight (kg)'], df['Age'], c='red', marker='o', alpha=0.5)
ax.set_xlabel('Height (cm)')
ax.set_ylabel('Weight (kg)')
ax.set_zlabel('Age')
ax.set_title('Height vs. Weight vs. Age')

plt.show()

df.to_csv('/content/drive/MyDrive/dummy_height_weight_age.csv', index=False)
# Out:
# Preview of dataset:
#    Height (cm)  Weight (kg)  Age
# 0          188   155.661859   26
# 1          178   134.545778   41
# 2          164   120.975504   18
# 3          192   145.855541   61
# 4          157    95.712288   25
#
# Mobel Evaluation
# Mean Squared Error: 0.037114
# Root Mean Squared Error: 0.192649
# R-squared: 0.946896
#
# Actual vs. Predicted Weights:
#
#    Actual Weight  Predicted Weight
# 0              1          1.230717
# 1              0         -0.040104
# 2              2          2.219703
# 3              1          1.349669
# 4              1          1.284293
